# %% [markdown]
# <a href="https://colab.research.google.com/github/lichinyuan/learn/blob/main/tibame20260212.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=3
print(a)
# Out:
# 3

# %% [markdown]
# 1.正統python 是.py做結尾
#
# 2.python工具叫做(Jupyter notebook):.ipynb結尾
#
# 3.colab:線上jupyter notebook環境
#
# 4.jupyter notebook的記事本:Markdown語法
#
# 5.還支援Latex Math，以$符號開始，$符號作結尾
#
# $area = \frac {1}{2} \pi r^2

# %%
print(a+2)
# Out:
# 5
